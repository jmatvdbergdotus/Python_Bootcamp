# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('whoops_wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myfile = open('whoops_wrong.txt')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops_wrong.txt'

# %%
pwd
# Out:
# 'C:\\Users\\Jane\\My Python Journey'

# %%
# you have to make sure that files are saved in the same location

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
#to open a text file that's at any location on your computer,
#you need to provide the full file path ("C\\Users\\Jane\\Test.txt")

# %%
# best practices -- you opened so please close it

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.readlines()

# %%
contents
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
with open('myfile.txt',mode='r') as myfile:
    contents = myfile.read()

# %% [markdown]
# ## Reading, Writing, Appending Modes
# ### - mode='r' is read only
# ### - mode='w' is write only (will overwrite or create new!!)
# ### - mode='a' is append only (will add on to files)
# ### - mode='r+' is reading and writing
# ### - mode='w+' is writing and reading (overwrites existing or creates a new file!)

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Overwriting my_new_file.txt

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt',mode='a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %%
with open('asdfghjkl.txt',mode='w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open('asdfghjkl.txt',mode='r') as f:
    print(f.read())
# Out:
# I CREATED THIS FILE!
