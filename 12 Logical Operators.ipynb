# %%
#key words are "and, or, not"

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2< 3
# Out:
# True

# %%
# the above examples are chaining comparisons without the use of the key words on the logical operators

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
1 == 1 or 2 == 2
# Out:
# True

# %%
100 == 1 or 2 == 2
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
not 400 > 5000
# Out:
# True
