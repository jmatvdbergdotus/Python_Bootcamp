# %% [markdown]
# Lists are ordered sequences that can hold a variety of object types. uses brackets and commas to separate objects in the list

# %%
my_list = [1,2,3]

# %%
my_list = ['STRING',100,23.2]

# %%
len(my_list)
# Out:
# 3

# %%
mylist = ["one", "two","three"]

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
another_list =["four","five"]

# %%
new_list = mylist + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list [0]='ONE ALL CAPS'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
for item in new_list:
    print(item)
# Out:
# ONE ALL CAPS
# two
# three
# four
# five

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
#.append allows you to add another item at the end of your list

# %%
#.pop is to remove an item from your list

# %%
new_list.pop()
# Out:
# 'six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
popped_item =new_list.pop()

# %%
popped_item
# Out:
# 'five'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four']

# %%
new_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['two', 'three', 'four']

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]
