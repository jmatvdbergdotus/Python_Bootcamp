# %%
#dictionaries are unordered mappings for storing objects. uses key-value pairing which allow users to quickly grab an object 
#without needing to know an index location.
#uses curly braces {} and colons : to signify the keys and their associated values

# %%
# {'key1':'value1','key2':'value2'}

# %%
# dictionaries - objects are retrieved by key name. unordered. cannot be sorted
# lists - objects are retrieved by location. ordered sequence. can be indexed or sliced.

# %%
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple':2.99,'oranges':1.99, 'milk':5.80}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1':123,'k2':['a','b','c'],'k3':{'insideKey':100}}

# %%
d['k2']
# Out:
# ['a', 'b', 'c']

# %%
d['k3']['insideKey']
# Out:
# 100

# %%
my_list = d['k2']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
letter = my_list[2]

# %%
letter
# Out:
# 'c'

# %%
letter.upper()
# Out:
# 'C'

# %%
d['k2'][2].upper()
# Out:
# 'C'

# %%
d = {'k1':100,'k2':200}

# %%
d
# Out:
# {'k1': 100, 'k2': 200}

# %%
d ['k3'] = 300

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d['k1'] = 'NEW VALUE'

# %%
d
# Out:
# {'k1': 'NEW VALUE', 'k2': 200, 'k3': 300}

# %%
d = {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300)])
