# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# Modulo or "Mod"Operator

# %%
7/4
# Out:
# 1.75

# %%
7%4
# Out:
# 3

# %% [markdown]
# it is to show the actual remainder of the division. good to use to  know if the number is an actual even number

# %%
20%2
# Out:
# 0

# %% [markdown]
# here we can also do powers.. like 2 to the power of 3

# %%
2**3
# Out:
# 8

# %% [markdown]
# basic order of operations with math

# %%
2+10*10+3
# Out:
# 105

# %% [markdown]
# 10*10 first then 2+3

# %%
(2+10)*(10+3)
# Out:
# 156
